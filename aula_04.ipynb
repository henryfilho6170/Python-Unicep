# %% [markdown]
# # Aula 04: Estruturas de Decisão - Resolução e Lista de Exercícios
#
# Nesta aula, não vamos aprender comandos novos! Vamos treinar o que aprendemos sobre `if`, `elif`, `else`, e os operadores lógicos `and`, `or`, `not` com bastante prática.

# %% [markdown]
# ## Como resolver um problema de programação?
#
# 1.  **Entenda o problema:** Leia com atenção o que está sendo pedido.
# 2.  **Identifique as Entradas e Saídas:** O que eu recebo do usuário? O que eu devo mostrar na tela?
# 3.  **Esboce o Passo a Passo (Algoritmo):** "Primeiro, peço o valor X. Depois verifico se X é maior que 10. Se sim, faço isso."
# 4.  **Codifique:** Transforme seu passo a passo em código Python.
# 5.  **Teste:** Execute com os valores de exemplo e veja se funciona.

# %% [markdown]
# ## Exemplo Resolvido 1: Ano Bissexto
#
# **O problema:** Crie um programa que peça um ano (ex: 2024) e informe se ele é Bissexto ou não.
#
# *Regra do Ano Bissexto:*
# Ele precisa ser múltiplo de 4 (`ano % 4 == 0`).
# Mas se for fim de século (múltiplo de 100), ele **não** é bissexto, a menos que ele também seja múltiplo de 400.

# %%
# Solução do Professor
ano = int(input("Digite o ano: "))

if (ano % 4 == 0 and ano % 100 != 0) or (ano % 400 == 0):
    print(f"O ano {ano} É bissexto!")
else:
    print(f"O ano {ano} NÃO é bissexto.")
# Out:
# O ano 2026 NÃO é bissexto.

# %% [markdown]
# ## Exemplo Resolvido 2: Calculadora Simples
#
# **O problema:** Peça dois números e um operador matemático (`+`, `-`, `*` ou `/`) ao usuário. Imprima o resultado da operação.

# %%
num1 = float(input("Digite o primeiro número: "))
op = input("Digite a operação (+, -, *, /): ")
num2 = float(input("Digite o segundo número: "))

if op == "+":
    print(f"Resultado: {num1 + num2}")
elif op == "-":
    print(f"Resultado: {num1 - num2}")
elif op == "*":
    print(f"Resultado: {num1 * num2}")
elif op == "/":
    # Cuidados extras em programação: não se divide por zero!
    if num2 == 0:
        print("Erro: Divisão por zero.")
    else:
        print(f"Resultado: {num1 / num2}")
else:
    print("Operador inválido!")
# Out:
# Resultado: 3.0

# %% [markdown]
# ---
#
# ## Lista de Exercícios
#
# Agora é a sua vez. Resolva os exercícios abaixo nas células vazias.
#
# ### Desafio 1: Vogal ou Consoante
# Faça um programa que verifique se uma letra digitada é vogal ou consoante. Lembre-se, vogais são `a`, `e`, `i`, `o`, `u`.

# %%
letra = input("Digite uma letra: ").lower()

# Seu código aqui

# %%
letra = input("digite uma letra:").lower()
if letra == "a" or letra == "e" or letra == "i" or letra == "o" or letra == "u":
  print("vogal")
else:
  print("consolante")
# Out:
# digite uma letra:a
# vogal

# %% [markdown]
# ### Desafio 2: Aumento de Salário
# Faça um programa que calcule o aumento de salário de um funcionário.
# - Para salários maiores que R$ 1500,00, aumento de 10%.
# - Para salários menores ou iguais a R$ 1500,00, aumento de 15%.
# Multiplicar um valor por 1.10 é dar 10% de aumento.

# %%
salario = float(input("Qual o salário atual? "))

# Seu código aqui

# %%
salario = float(input("qual o salario atua?"))

if salario > 1500:
  novo_salario = salario * 1.10
  print(f"o novo salario e {novo_salario}")
else:
  novo_salario = salario * 1.15
  print(F"o novo salario e {novo_salario}")
# Out:
# qual o salario atua?1000
# o novo salario e 1150.0

# %% [markdown]
# ### Desafio 3: Triângulos
# Peça os 3 lados de um triângulo. O programa deverá informar se os valores formam um triângulo. Caso formem, diga o tipo do triângulo:
# - Equilátero: 3 lados iguais;
# - Isósceles: 2 lados iguais;
# - Escaleno: 3 lados diferentes.
# *Dica: Para formar um triângulo, a soma de quaisquer dois lados precisa ser maior que o terceiro lado.*

# %%
# Seu código aqui

# %% [markdown]
# ### Exercício 1: Número Par ou Ímpar
#
# Peça ao usuário para digitar um número inteiro. Use uma estrutura de decisão para verificar se o número é par ou ímpar e imprima o resultado.

# %%
numero = int(input("digite um numero inteiro"))

if numero % 2 == 0:
    print(f"O número {numero} é par.")
else:
    print(f"O número {numero} é ímpar.")

# %% [markdown]
# umer### Exercício 2: Maior de Dois Números
#
# Peça ao usuário para digitar dois números inteiros. Determine qual deles é o maior e imprima-o.

# %%
num1 = int(input("digite o primeiro numero"))
num2 = int(input("digite o segundo numero"))

if num1 > num2:
  print(f"o maior numero e {num1}")
else:
  print(F"o maior numero e {num2}")
# Out:
# digite o primeiro numero1
# digite o segundo numero2
# o maior numero e 2

# %% [markdown]
# ### Exercício 3: Faixa Etária
#
# Peça ao usuário para digitar sua idade. Com base na idade, imprima se a pessoa é 'Criança' (0-12), 'Adolescente' (13-17) ou 'Adulto' (18 ou mais).

# %%
idade = int(input("digite sua idade:"))
if idade <= 12:
  print("crianca")
elif idade <= 17:
  print("adolescente")
else:
  print("adulto")
# Out:
# digite sua idade:18
# adulto

# %% [markdown]
# ### Exercício 4: Verificação de Login Simples
#
# Peça ao usuário um nome de usuário (`admin`) e uma senha (`1234`). Verifique se ambos estão corretos. Se sim, imprima 'Login bem-sucedido!'; caso contrário, imprima 'Credenciais inválidas!'.

# %%
usuario = input("digite seu usuario:")
senha = input("digite sua senha:")
if usuario == "admin" and senha == "1234":
  print("login bem-sucedido")
else:
  print("credenciais invalidas")
# Out:
# digite seu usuario:admin
# digite sua senha:1234
# login bem-sucedido

# %% [markdown]
# ### Exercício 5: Múltiplo de 5 e 7
#
# Peça ao usuário para digitar um número inteiro. Verifique se o número é múltiplo de 5 **e** de 7. Imprima uma mensagem apropriada.

# %%
numero = int(input("digite um numero:"))

if numero % 5 == 0 and numero %7 == 0:
  print(f"O numero {numero} e multiplo de 5 e 7")
else:
  print (f"O numero {numero} nao e multiplo de 5 e 7")
# Out:
# digite um numero:6
# O numero 6 nao e multiplo de 5 e 7

# %% [markdown]
# ### Exercício 6: Classificação de Triângulos (Com Validação)
#
# Peça ao usuário para digitar os comprimentos de três lados de um potencial triângulo. Primeiro, verifique se os lados podem formar um triângulo (a soma de quaisquer dois lados deve ser maior que o terceiro). Se for um triângulo, classifique-o como 'Equilátero', 'Isósceles' ou 'Escaleno'. Caso contrário, informe que os lados não formam um triângulo.

# %%
a = float(input("digite o primeiro lado:"))
b = float(input("digite o segundo lado:"))
c = float(input("digite o terceiro lado:"))

# Primeiro, verifica se os lados podem formar um triângulo
if (a + b > c) and (a + c > b) and (b + c > a):
    if a == b and a == c:
        print("equilatero")
    elif a == b or a == c or b == c:
        print("isocelles")
    else:
        print("escaleno")
else:
    print("nao e um triangulo")
# Out:
# digite o primeiro lado:2
# digite o segundo lado:3
# digite o terceiro lado:3
# isocelles

# %% [markdown]
# ### Exercício 7: Aprovação de Empréstimo
#
# Uma instituição financeira tem as seguintes regras para aprovar um empréstimo:
# - O solicitante deve ter idade entre 25 e 60 anos (inclusive).
# - A renda mensal deve ser de pelo menos R$ 2000.
# - O score de crédito deve ser igual ou superior a 700.
#
# Peça ao usuário sua idade, renda mensal e score de crédito. Determine se o empréstimo pode ser aprovado ou não e imprima o resultado.

# %%
idade = int(input("digite sua idade:"))
renda = float(Input("digite sua renda mensal:"))
score = int(input("digite seu score de credito:"))

if idade >=25 and idade <=60 and renda >=2000 and score >= 700:
  print("emprestimo aprovado")
else:
  print("emprestimo negado")

# %% [markdown]
# ### Exercício 8: Dia da Semana Válido
#
# Peça ao usuário para digitar um número de 1 a 7, representando os dias da semana (1 para domingo, 2 para segunda, etc.). Se o número for válido, imprima o nome do dia correspondente. Se for inválido, imprima 'Número inválido para dia da semana!'.

# %%
dia = input("digite um numero de 1 a 7:")
if dia == 1:
  print("domingo")
elif dia == 2:
  print("segunda")
elif dia == 3:
  print("terca")
elif dia == 4:
  print("quarta")
elif dia == 5:
  prit("quinta")
elif dia == 6:
  print("sexta")
elif dia == 7:
  print ("sabado")
else:
  print("numero invalido")
# Out:
# digite um numero de 1 a 7:5
# numero invalido

# %% [markdown]
# ### Exercício 9: Cálculo de Desconto Complexo
#
# Uma loja oferece descontos baseados em: tipo de cliente e valor da compra.
# - Clientes 'VIP' têm 15% de desconto se a compra for acima de R$ 1000, ou 10% se for até R$ 1000.
# - Clientes 'Normal' têm 5% de desconto se a compra for acima de R$ 500, ou nenhum desconto caso contrário.
#
# Peça ao usuário o tipo de cliente (VIP ou Normal) e o valor total da compra. Calcule o valor final após o desconto.

# %%
tipo = input("digite seu tipo de cliente (vip ou nomrma):").lower()
valor = float(input("digite o vamor da compra:"))
desconto = 0

if tipo == "vip":
 if valor > 1000:
  desconto = 0.15

elif tipo == "normal":
  if valor > 500:
    desconto = 0.05

    valor_final = valor - ( valor * desconto )
    print(f"o valor final: R$", valor_final)
# Out:
# digite seu tipo de cliente (vip ou nomrma):normal
# digite o vamor da compra:1000
# o valor final: R$ 950.0

# %% [markdown]
# ### Exercício 10: Validação de Data (Dia e Mês)
#
# Peça ao usuário para digitar um dia e um mês (como números inteiros). Valide se a data é logicamente possível (por exemplo, 30 de Fevereiro não é possível, 31 de Abril não é possível). Considere que Fevereiro tem 28 dias para este exercício. Imprima se a data é 'Válida' ou 'Inválida'.

# %%
dia = int(input("Digite o dia: "))
mes = int(input("Digite o mês: "))

if mes < 1 or mes > 12:
    print("Data inválida")

else:
    if mes == 2:
        if 1 <= dia <= 28:
            print("Data válida")
        else:
            print("Data inválida")

    elif mes in [4, 6, 9, 11]:
        if 1 <= dia <= 30:
            print("Data válida")
        else:
            print("Data inválida")

    else:
        if 1 <= dia <= 31:
            print("Data válida")
        else:
            print("Data inválida")
